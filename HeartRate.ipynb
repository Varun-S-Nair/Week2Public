# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
df=pd.read_csv('/Users/varun/Desktop/BeaverWorks/week2/VarunNairHeartbeat.csv', sep=',',header=1)
df
df = df[5:6006]
df
# Out:
#        Duration:  2 0
# 5       '0:0:0.0  373
# 6      '0:0:0.02  362
# 7      '0:0:0.04  351
# 8      '0:0:0.06  346
# 9      '0:0:0.08  346
# 10      '0:0:0.1  347
# 11     '0:0:0.12  347
# 12     '0:0:0.14  348
# 13     '0:0:0.16  349
# 14     '0:0:0.18  349
# 15      '0:0:0.2  349
# 16     '0:0:0.22  352
# 17     '0:0:0.24  357
# 18     '0:0:0.26  362
# 19     '0:0:0.28  367
# 20      '0:0:0.3  370
# 21     '0:0:0.32  369
# 22     '0:0:0.34  369
# 23     '0:0:0.36  370
# 24     '0:0:0.38  371
# 25      '0:0:0.4  371
# 26     '0:0:0.42  371
# 27     '0:0:0.44  372
# 28     '0:0:0.46  372
# 29     '0:0:0.48  373
# 30      '0:0:0.5  373
# 31     '0:0:0.52  374
# 32     '0:0:0.54  374
# 33     '0:0:0.56  374
# 34     '0:0:0.58  375
# ...          ...  ...
# 5976  '0:1:59.42  369
# 5977  '0:1:59.44  368
# 5978  '0:1:59.46  367
# 5979  '0:1:59.48  367
# 5980   '0:1:59.5  368
# 5981  '0:1:59.52  369
# 5982  '0:1:59.54  370
# 5983  '0:1:59.56  370
# 5984  '0:1:59.58  371
# 5985   '0:1:59.6  371
# 5986  '0:1:59.62  372
# 5987  '0:1:59.64  372
# 5988  '0:1:59.66  372
# 5989  '0:1:59.68  372
# 5990   '0:1:59.7  372
# 5991  '0:1:59.72  372
# 5992  '0:1:59.74  371
# 5993  '0:1:59.76  371
# 5994  '0:1:59.78  372
# 5995   '0:1:59.8  377
# 5996  '0:1:59.82  389
# 5997  '0:1:59.84  400
# 5998  '0:1:59.86  406
# 5999  '0:1:59.88  406
# 6000   '0:1:59.9  402
# 6001  '0:1:59.92  397
# 6002  '0:1:59.94  390
# 6003  '0:1:59.96  384
# 6004  '0:1:59.98  380
# 6005   '0:1:60.0  377
#
# [6001 rows x 2 columns]

# %%
ppg=df.values[:,1].astype(np.double)
ppg
# Out:
# array([373., 362., 351., ..., 384., 380., 377.])

# %%
import matplotlib
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fs = 128
t = np.arange(ppg.shape[0])/fs
ax.plot(t,ppg)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='PPG')
plt.xlim(0,10)
ax.grid()
fig.savefig("test.png")
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
peaks, _ = find_peaks(x, distance=150)
np.diff(peaks)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.show()
